# %% [markdown]
# <a href="https://colab.research.google.com/github/rakshansingh12/disease-risk-prediction-ml/blob/main/01_project_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

PROJECT_PATH = "/content/drive/MyDrive/disease-risk-prediction-gene-expression"

folders = [
    "data/raw",
    "data/processed",
    "notebooks",
    "results"
]

for folder in folders:
    os.makedirs(os.path.join(PROJECT_PATH, folder), exist_ok=True)

print("Project folders created.")
# Out:
# Project folders created.

# %%
# !pip install numpy pandas scikit-learn matplotlib seaborn scipy

# %%
import numpy as np
import pandas as pd
import sklearn

print("NumPy:", np.__version__)
print("Pandas:", pd.__version__)
print("Scikit-learn:", sklearn.__version__)
# Out:
# NumPy: 2.0.2
# Pandas: 2.2.2
# Scikit-learn: 1.6.1
