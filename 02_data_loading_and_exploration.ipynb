# %% [markdown]
# <a href="https://colab.research.google.com/github/rakshansingh12/disease-risk-prediction-ml/blob/main/02_data_loading_and_exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

PROJECT_PATH = "/content/drive/MyDrive/disease-risk-prediction-gene-expression"
RAW_DATA_PATH = os.path.join(PROJECT_PATH, "data/raw")

os.listdir(RAW_DATA_PATH)
# Out:
# ['GSE5281_expression_matrix.txt.gz', 'GPL570_annotation.txt']

# %%
import pandas as pd

file_path = os.path.join(RAW_DATA_PATH, "GSE5281_expression_matrix.txt.gz")

data = pd.read_csv(
    file_path,
    sep="\t",
    compression="gzip",
    comment="!",
    index_col=0
)

# %%
data.shape
# Out:
# (54675, 161)

# %%
X_full = data.T

# %%
data.head()
# Out:
#             GSM119615   GSM119616    GSM119617    GSM119618   GSM119619  \
# ID_REF
# 1007_s_at  693.973300  807.145140  1722.625000  1668.057500  2231.29690
# 1053_at      9.755318   19.052270    13.060389    14.652245   138.67683
# 117_at      13.346846   18.217276    97.425470    98.197945   106.46844
# 121_at     173.092450  289.315400   537.182800   496.346560   477.86517
# 1255_g_at   52.616950  110.375984    99.021736    17.306772   628.81616
#
#             GSM119620   GSM119621    GSM119622   GSM119623   GSM119624  ...  \
# ID_REF                                                                  ...
# 1007_s_at  990.541000  1396.82420  1026.056500  736.770300  938.817100  ...
# 1053_at      7.186742    10.17089    34.056934    7.829473   40.235332  ...
# 117_at      98.710520   164.32666    46.306164   35.067910   72.864900  ...
# 121_at     355.092000   467.56790   294.583280  224.524060  298.284730  ...
# ...

# %%
X_full.shape
# Out:
# (161, 54675)

# %%
sample = X_full.iloc[0].values

# %%
sample.shape
# Out:
# (54675,)

# %%
import numpy as np

np.savetxt(
    "example_sample.csv",
    sample.reshape(1, -1),
    delimiter=","
)

# %%
data.index[:5]
# Out:
# Index(['1007_s_at', '1053_at', '117_at', '121_at', '1255_g_at'], dtype='object', name='ID_REF')

# %%
data.columns[:5]
# Out:
# Index(['GSM119615', 'GSM119616', 'GSM119617', 'GSM119618', 'GSM119619'], dtype='object')

# %%
X = data.T
X.shape
# Out:
# (161, 54675)

# %% [markdown]
# We have gene expression measurements for 54,675 (columns) genes across 161 (rows) human samples.
